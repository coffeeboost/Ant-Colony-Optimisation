# %% [markdown]
# # Analyzing data from Python
# ## Steps:
# ## 1. import libraries
# ## 2. import data
# ## 3. fix time column
# ## 4. plot pheremone against time

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./weWinThese.csv')

# %%
data
# Out:
#     time  1  2  3  4  5   p1         p2   p3         p4   p5        p6   p7  \
# 0    100  a  c  b  d  a  0.0   0.000000  0.0   0.000000  0.0  0.000000  0.0
# 1     99  a  c  b  d  a  0.0   0.900000  0.0   0.000000  0.0  0.900000  0.0
# 2     98  a  c  d  b  a  0.0   1.710000  0.0   0.000000  0.0  1.710000  0.0
# 3     97  a  c  d  b  a  0.0   6.039000  0.0   4.500000  0.0  1.539000  0.0
# 4     96  a  c  d  b  a  0.0   9.935100  0.0   8.550000  0.0  1.385100  0.0
# ..   ... .. .. .. .. ..  ...        ...  ...        ...  ...       ...  ...
# 95     5  a  c  d  b  a  0.0  26.812539  0.0  22.266179  0.0  4.546359  0.0
# 96     4  a  c  b  d  a  0.0  28.631285  0.0  24.539561  0.0  4.091723  0.0
# 97     3  a  c  b  d  a  0.0  26.668156  0.0  22.085605  0.0  4.582551  0.0
# 98     2  a  c  d  b  a  0.0  24.901341  0.0  19.877045  0.0  5.024296  0.0
# 99     1  a  c  b  d  a  0.0  26.911207  0.0  22.389340  0.0  4.521866  0.0
#
#           p8         p9       p10        p11  p12
# ...

# %%
data['time'] = abs(data['time'] - len(data))

# %%
data
# Out:
#     time  1  2  3  4  5   p1         p2   p3         p4   p5        p6   p7  \
# 0      0  a  c  b  d  a  0.0   0.000000  0.0   0.000000  0.0  0.000000  0.0
# 1      1  a  c  b  d  a  0.0   0.900000  0.0   0.000000  0.0  0.900000  0.0
# 2      2  a  c  d  b  a  0.0   1.710000  0.0   0.000000  0.0  1.710000  0.0
# 3      3  a  c  d  b  a  0.0   6.039000  0.0   4.500000  0.0  1.539000  0.0
# 4      4  a  c  d  b  a  0.0   9.935100  0.0   8.550000  0.0  1.385100  0.0
# ..   ... .. .. .. .. ..  ...        ...  ...        ...  ...       ...  ...
# 95    95  a  c  d  b  a  0.0  26.812539  0.0  22.266179  0.0  4.546359  0.0
# 96    96  a  c  b  d  a  0.0  28.631285  0.0  24.539561  0.0  4.091723  0.0
# 97    97  a  c  b  d  a  0.0  26.668156  0.0  22.085605  0.0  4.582551  0.0
# 98    98  a  c  d  b  a  0.0  24.901341  0.0  19.877045  0.0  5.024296  0.0
# 99    99  a  c  b  d  a  0.0  26.911207  0.0  22.389340  0.0  4.521866  0.0
#
#           p8         p9       p10        p11  p12
# ...

# %%
lines = [x for x in data.columns if x[0] == 'p']

ax = plt.gca()

for y in lines:
    data.plot(kind='line',x='time',y=y, ax=ax)

plt.savefig("everything")
plt.show()

# %%
a = data.iloc[len(data)-1][6:]

# %%
a = a[a>0]
a
# Out:
# p2     26.9112
# p4     22.3893
# p6     4.52187
# p8     4.52187
# p9     22.3893
# p10    4.52187
# p11    22.3893
# Name: 99, dtype: object

# %%
keep = ['time','1','2','3','4','5'] + list(a.index)

# %%
data = data[keep]

# %%
data
# Out:
#     time  1  2  3  4  5         p2         p4        p6        p8         p9  \
# 0      0  a  c  b  d  a   0.000000   0.000000  0.000000  0.000000   0.000000
# 1      1  a  c  b  d  a   0.900000   0.000000  0.900000  0.900000   0.000000
# 2      2  a  c  d  b  a   1.710000   0.000000  1.710000  1.710000   0.000000
# 3      3  a  c  d  b  a   6.039000   4.500000  1.539000  1.539000   4.500000
# 4      4  a  c  d  b  a   9.935100   8.550000  1.385100  1.385100   8.550000
# ..   ... .. .. .. .. ..        ...        ...       ...       ...        ...
# 95    95  a  c  d  b  a  26.812539  22.266179  4.546359  4.546359  22.266179
# 96    96  a  c  b  d  a  28.631285  24.539561  4.091723  4.091723  24.539561
# 97    97  a  c  b  d  a  26.668156  22.085605  4.582551  4.582551  22.085605
# 98    98  a  c  d  b  a  24.901341  19.877045  5.024296  5.024296  19.877045
# 99    99  a  c  b  d  a  26.911207  22.389340  4.521866  4.521866  22.389340
#
#          p10        p11
# ...

# %%
lines = [x for x in data.columns if x[0] == 'p']

ax = plt.gca()

for y in lines:
    data.plot(kind='line',x='time',y=y, ax=ax)

plt.savefig("notEverything")
plt.show()
